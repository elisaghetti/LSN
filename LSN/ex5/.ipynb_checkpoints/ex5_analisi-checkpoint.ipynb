# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
file = "Orbital_1s.csv"
df=pd.read_csv(file, sep='\t',header = None, names= ['x','y','z'])
df.head()
# Out:
#           x         y         z
# 0  0.018124  0.032927  0.092668
# 1 -0.018529  0.098457  0.026620
# 2 -0.108283  0.054951  0.033803
# 3 -0.039714  0.096090 -0.026246
# 4  0.033407  0.046722 -0.073322

# %%
fig = plt.figure()
ax = fig.add_subplot(projection='3d')
ax.scatter(df['x'],df['y'],df['z'], c=df['z'], marker='.')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
ax.view_init(10, 30)

plt.show()

# %%
fig = plt.figure(figsize=(10, 7))
ax = fig.add_subplot(111, projection='3d')
# Colori distinti per ogni random walk

ax.plot(df['x'], df['y'], df['z'])

# Etichette e legenda
ax.set_xlabel("X")
ax.set_ylabel("Y")
ax.set_zlabel("Z")
ax.set_title("Primi 10 Random Walks")
ax.legend()

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 5
#       2 ax = fig.add_subplot(111, projection='3d')
#       3 # Colori distinti per ogni random walk
# ----> 5 ax.plot(df['x'], df['y'], df['z'], c=df['z'])
#       7 # Etichette e legenda
#       8 ax.set_xlabel("X")
#
# File ~/miniconda3/lib/python3.12/site-packages/mpl_toolkits/mplot3d/axes3d.py:1986, in Axes3D.plot(self, xs, ys, zdir, axlim_clip, *args, **kwargs)
#    1982     zs = kwargs.pop('zs', 0)
#    1984 xs, ys, zs = cbook._broadcast_with_masks(xs, ys, zs)
# -> 1986 lines = super().plot(xs, ys, *args, **kwargs)
#    1987 for line in lines:
#    1988     art3d.line_2d_to_3d(line, zs=zs, zdir=zdir, axlim_clip=axlim_clip)
#
# File ~/miniconda3/lib/python3.12/site-packages/matplotlib/axes/_axes.py:1777, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1534 """
# ...
