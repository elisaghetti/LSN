# %% [markdown]
# è un po' strana la cauchy lorentz, soprattutto per N=10, ricontrollare

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import math

# %%
file = "SN_exp.csv"
df = pd.read_csv(file, sep ='\t',header=None, names = ['N','S_N'])
df.head()
# Out:
#    N       S_N
# 0  1  0.130849
# 1  1  0.402219
# 2  1  1.220880
# 3  1  2.358980
# 4  1  1.496320

# %%
N_values = df['N'].unique()
colors = ['blue', 'red', 'green', 'orange']

plt.figure(figsize=(10, 6))
for i,val in enumerate(N_values):
    plt.hist(df[df['N'] == val]['S_N'], edgecolor = 'black', density=True, color=colors[i%len(colors)],label=f'N = {val}')
    plt.xlabel('Valori')
    plt.ylabel('Frequenza')
    plt.title('Esponenziale')
    plt.legend()
    plt.grid(True, linestyle='--', alpha=0.6)
plt.show()

# %%
file = "SN_unif.csv"
df = pd.read_csv(file, sep ='\t',header=None, names = ['N','S_N'])
df.head()
# Out:
#    N       S_N
# 0  1  0.169918
# 1  1  0.477115
# 2  1  0.086007
# 3  1  0.371496
# 4  1  0.021138

# %%
N_values = df['N'].unique()
colors = ['blue', 'red', 'green', 'orange']

plt.figure(figsize=(10, 6))
for i,val in enumerate(N_values):
    plt.hist(df[df['N'] == val]['S_N'], edgecolor = 'black', density=True, color=colors[i%len(colors)],label=f'N = {val}')
    plt.xlabel('Valori')
    plt.ylabel('Frequenza')
    plt.title('Uniforme')
    plt.legend()
    plt.grid(True, linestyle='--', alpha=0.6)
plt.show()

# %%
file = "SN_cauchy.csv"
df = pd.read_csv(file, sep ='\t',header=None, names = ['N','S_N'])
df.head()
# Out:
#    N       S_N
# 0  1  0.879663
# 1  1  0.229586
# 2  1  0.533577
# 3  1  1.773410
# 4  1 -1.711400

# %%
N_values = df['N'].unique()
colors = ['blue', 'red', 'green', 'orange']

plt.figure(figsize=(10, 6))
for i,val in enumerate(N_values):
    plt.hist(df[df['N'] == val]['S_N'], bins=100,edgecolor = 'black', density=True, color=colors[i%len(colors)],label=f'N = {val}')
    plt.xlabel('Valori')
    plt.xlim(-2000,1000)
    plt.ylabel('Frequenza')
    plt.title('Cauchy-Lorentz')
    plt.legend()
    plt.grid(True, linestyle='--', alpha=0.6)
plt.show()
