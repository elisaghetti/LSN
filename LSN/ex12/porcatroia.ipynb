# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
import os
import numpy as np
import matplotlib.pyplot as plt
seed=0
np.random.seed(seed) # fix random seed
tf.random.set_seed(seed)
from PIL import Image
import os
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
import os
import numpy as np
import matplotlib.pyplot as plt
seed=0
np.random.seed(seed) # fix random seed
tf.random.set_seed(seed)



final_model = keras.models.load_model("./OUTPUT/final_model.keras")

# %%
import numpy as np
X_test=np.load('./OUTPUT/final_X_test.npy')
Y_test=np.load('./OUTPUT/final_Y_test.npy')

# %%
import matplotlib.pyplot as plt
predictions = final_model.predict(X_test)
plt.figure(figsize=(15, 15)) 

X_test=X_test.reshape(X_test.shape[0],28,28,1)
for i in range(10):    
    ax = plt.subplot(2, 10, i + 1)    
    plt.imshow(X_test[i, :, :, 0], cmap='gray')    
    plt.title("Digit: {}\nPredicted:    {}".format(np.argmax(Y_test[i]), np.argmax(predictions[i])))    
    plt.axis('off') 
plt.show()
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
import os
import numpy as np
import matplotlib.pyplot as plt
seed=0
np.random.seed(seed) # fix random seed
tf.random.set_seed(seed)
from PIL import Image
import os
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
import os
import numpy as np
import matplotlib.pyplot as plt
seed=0
np.random.seed(seed) # fix random seed
tf.random.set_seed(seed)



final_model = keras.models.load_model("./OUTPUT/final_model.keras")
digit_filename = "./digits/1tommi.png"
digit_in = Image.open(digit_filename).convert('L')
ydim, xdim = digit_in.size
print("Image size: "+str(xdim)+"x"+str(ydim))
pix=digit_in.load();
data = np.zeros((xdim, ydim))
for j in range(ydim):
 for j in range(ydim):
    for i in range(xdim):
        data[i,j]=pix[j,i]
print("Min pixel:", data.min())
print("Max pixel:", data.max())
data /= 255

data=data.reshape(1,xdim,ydim,1)
print(data.shape)
pred= final_model.predict(data)
print(pred)
data = data.reshape(xdim,ydim)
fig,ax=plt.subplots(1,2,figsize=(12,9))
  
ax[0].imshow(data, cmap='gray')    
ax[0].set_title("Digit predicted:    {}".format(np.argmax(pred)))
ax[0].axis('off') 
bins=np.linspace(0,10,10)
ax[1].scatter(bins,pred)
# Out:
# Image size: 28x28
# Min pixel: 0.0
# Max pixel: 251.0
# (1, 28, 28, 1)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 445ms/step
# [[0.10359694 0.09664133 0.10073653 0.09393668 0.09716459 0.09164426
#   0.08969322 0.10851111 0.11811853 0.09995685]]
